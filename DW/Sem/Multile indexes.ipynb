# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(dict(
    id = [86, 8, 2, 90, 79, 77],
    names='sainath ansh abhi dherraj koushik hrishikesh'.split(' '),
    marks = list(map(int, '98 67 56 45 28 51'.split(' '))),
    town = 'Hyd Hyd Hyd Hyd Warangle Nizamabad'.split(' '),
    area = 'Sec Suchitra Chintal Amerpet Maisamaguda Maisamaguda'.split(' '),
))
df
# Out:
#    id       names  marks       town         area
# 0  86     sainath     98        Hyd          Sec
# 1   8        ansh     67        Hyd     Suchitra
# 2   2        abhi     56        Hyd      Chintal
# 3  90     dherraj     45        Hyd      Amerpet
# 4  79     koushik     28   Warangle  Maisamaguda
# 5  77  hrishikesh     51  Nizamabad  Maisamaguda

# %%
df1 = df.set_index(['area', 'town'], drop=1)
df1
# Out:
#                        id       names  marks
# area        town
# Sec         Hyd        86     sainath     98
# Suchitra    Hyd         8        ansh     67
# Chintal     Hyd         2        abhi     56
# Amerpet     Hyd        90     dherraj     45
# Maisamaguda Warangle   79     koushik     28
#             Nizamabad  77  hrishikesh     51

# %%
df2 = df.set_index(['town', 'area'], drop=1)

# %%
df2
# Out:
#                        id       names  marks
# town      area
# Hyd       Sec          86     sainath     98
#           Suchitra      8        ansh     67
#           Chintal       2        abhi     56
#           Amerpet      90     dherraj     45
# Warangle  Maisamaguda  79     koushik     28
# Nizamabad Maisamaguda  77  hrishikesh     51

# %%
print(list(df2.index))
print(df1.index)
# Out:
# [('Hyd', 'Sec'), ('Hyd', 'Suchitra'), ('Hyd', 'Chintal'), ('Hyd', 'Amerpet'), ('Warangle', 'Maisamaguda'), ('Nizamabad', 'Maisamaguda')]
# MultiIndex([(        'Sec',       'Hyd'),
#             (   'Suchitra',       'Hyd'),
#             (    'Chintal',       'Hyd'),
#             (    'Amerpet',       'Hyd'),
#             ('Maisamaguda',  'Warangle'),
#             ('Maisamaguda', 'Nizamabad')],
#            names=['area', 'town'])

# %%
df1.loc[(slice(None),'Hyd'), :]
# Out:
#                id    names  marks
# area     town
# Sec      Hyd   86  sainath     98
# Suchitra Hyd    8     ansh     67
# Chintal  Hyd    2     abhi     56
# Amerpet  Hyd   90  dherraj     45

# %%
df1
# Out:
#                        id       names  marks
# area        town
# Sec         Hyd        86     sainath     98
# Suchitra    Hyd         8        ansh     67
# Chintal     Hyd         2        abhi     56
# Amerpet     Hyd        90     dherraj     45
# Maisamaguda Warangle   79     koushik     28
#             Nizamabad  77  hrishikesh     51

# %%
df2
# Out:
#                        id       names  marks
# town      area
# Hyd       Sec          86     sainath     98
#           Suchitra      8        ansh     67
#           Chintal       2        abhi     56
#           Amerpet      90     dherraj     45
# Warangle  Maisamaguda  79     koushik     28
# Nizamabad Maisamaguda  77  hrishikesh     51

# %%
df2.loc[(slice(None), ['Amerpet', 'Maisamaguda']), :]
# Out:
#                        id       names  marks
# town      area
# Hyd       Amerpet      90     dherraj     45
# Warangle  Maisamaguda  79     koushik     28
# Nizamabad Maisamaguda  77  hrishikesh     51

# %%
df2.sort_index()
# Out:
#                        id       names  marks
# town      area
# Hyd       Amerpet      90     dherraj     45
#           Chintal       2        abhi     56
#           Sec          86     sainath     98
#           Suchitra      8        ansh     67
# Nizamabad Maisamaguda  77  hrishikesh     51
# Warangle  Maisamaguda  79     koushik     28

# %%
dff = pd.DataFrame(dict(
    id = [86, 8, 2, 90, 79, 77],
    names='sainath ansh abhi koushik hrishikesh dheeraj'.split(' '),
    marks = list(map(int, '98 67 56 45 28 51'.split(' '))),
    town = 'Hyd Hyd Hyd Warangle Nizamabad Hyd'.split(' '),
    area = 'Sec Suchitra Chintal Maisamaguda Maisamaguda Amerpet'.split(' ')
))
dff
# Out:
#    id       names  marks       town         area
# 0  86     sainath     98        Hyd          Sec
# 1   8        ansh     67        Hyd     Suchitra
# 2   2        abhi     56        Hyd      Chintal
# 3  90     koushik     45   Warangle  Maisamaguda
# 4  79  hrishikesh     28  Nizamabad  Maisamaguda
# 5  77     dheeraj     51        Hyd      Amerpet

# %%
dff1 = dff.set_index(['town', 'area'])
dff1
# Out:
#                        id       names  marks
# town      area
# Hyd       Sec          86     sainath     98
#           Suchitra      8        ansh     67
#           Chintal       2        abhi     56
# Warangle  Maisamaguda  90     koushik     45
# Nizamabad Maisamaguda  79  hrishikesh     28
# Hyd       Amerpet      77     dheeraj     51

# %%
sdff1 = dff1.sort_index()
sdff1.index
# Out:
# MultiIndex([(      'Hyd',     'Amerpet'),
#             (      'Hyd',     'Chintal'),
#             (      'Hyd',         'Sec'),
#             (      'Hyd',    'Suchitra'),
#             ('Nizamabad', 'Maisamaguda'),
#             ( 'Warangle', 'Maisamaguda')],
#            names=['town', 'area'])

# %%
names = 'sai abhi ram'.split(' ')
weights = [75, 74, 87]
d = {i:j for i, j in zip(names, weights)}

# %%
d
# Out:
# {'sai': 75, 'abhi': 74, 'ram': 87}

# %%
g = 23
def f():
    global g
    g = 21
print('Value of g before running f(): ', g)
f()
print('Value of g after running f(): ', g)
# Out:
# Value of g before running f():  23
# Value of g after running f():  21

# %%
df
# Out:
#    id       names  marks       town         area
# 0  86     sainath     98        Hyd          Sec
# 1   8        ansh     67        Hyd     Suchitra
# 2   2        abhi     56        Hyd      Chintal
# 3  90     dherraj     45        Hyd      Amerpet
# 4  79     koushik     28   Warangle  Maisamaguda
# 5  77  hrishikesh     51  Nizamabad  Maisamaguda

# %%
df['marks']>40
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# Name: marks, dtype: bool

# %%
df.mean()
# Out:
# C:\Users\Sainath\AppData\Local\Temp\ipykernel_15896\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# id       57.0
# marks    57.5
# dtype: float64

# %%
pd.Series(['BMW', 'Honda'])
# Out:
# 0      BMW
# 1    Honda
# dtype: object

# %%
pd.Series(['BMW', 'Honda'], name='ss')
# Out:
# 0      BMW
# 1    Honda
# Name: ss, dtype: object

# %%
stu = pd.DataFrame({
    'name':['sai', 'abhi', 'ram', 'uday'],
    'student':[True, False, True, False]
})
stu
# Out:
#    name  student
# 0   sai     True
# 1  abhi    False
# 2   ram     True
# 3  uday    False

# %%
stu[~stu['student']]
# Out:
#    name  student
# 1  abhi    False
# 3  uday    False

# %%
stu['student']
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# Name: student, dtype: bool

# %%
stu
# Out:
#    name  student
# 0   sai     True
# 1  abhi    False
# 2   ram     True
# 3  uday    False

# %%
new_s = pd.DataFrame({
    'name':['krishna'],
    'student':[True]
})
pd.concat([stu,new_s], ignore_index=True)
# Out:
#       name  student
# 0      sai     True
# 1     abhi    False
# 2      ram     True
# 3     uday    False
# 4  krishna     True

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
response = requests.get('https://books.toscrape.com/').content

# %%
soup = bs(response, 'html.parser')
book_titles = [i.text for i in soup.select('h3 a')]
book_titles[:5]
# Out:
# ['A Light in the ...',
#  'Tipping the Velvet',
#  'Soumission',
#  'Sharp Objects',
#  'Sapiens: A Brief History ...']

# %%
soup.select('h3 a')
# Out:
# [<a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a>,
#  <a href="catalogue/tipping-the-velvet_999/index.html" title="Tipping the Velvet">Tipping the Velvet</a>,
#  <a href="catalogue/soumission_998/index.html" title="Soumission">Soumission</a>,
#  <a href="catalogue/sharp-objects_997/index.html" title="Sharp Objects">Sharp Objects</a>,
#  <a href="catalogue/sapiens-a-brief-history-of-humankind_996/index.html" title="Sapiens: A Brief History of Humankind">Sapiens: A Brief History ...</a>,
#  <a href="catalogue/the-requiem-red_995/index.html" title="The Requiem Red">The Requiem Red</a>,
#  <a href="catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html" title="The Dirty Little Secrets of Getting Your Dream Job">The Dirty Little Secrets ...</a>,
# ...

# %%
products = requests.get('https://jsonplaceholder.typicode.com/posts')
pd.DataFrame(products.json())
# Out:
#     userId   id                                              title  \
# 0        1    1  sunt aut facere repellat provident occaecati e...
# 1        1    2                                       qui est esse
# 2        1    3  ea molestias quasi exercitationem repellat qui...
# 3        1    4                               eum et est occaecati
# 4        1    5                                 nesciunt quas odio
# ..     ...  ...                                                ...
# 95      10   96  quaerat velit veniam amet cupiditate aut numqu...
# 96      10   97         quas fugiat ut perspiciatis vero provident
# 97      10   98                        laboriosam dolor voluptates
# 98      10   99  temporibus sit alias delectus eligendi possimu...
# 99      10  100              at nam consequatur ea labore ea harum
#
#                                                  body
# 0   quia et suscipit\nsuscipit recusandae consequu...
# ...

# %%
products.json()
# Out:
# [{'userId': 1,
#   'id': 1,
#   'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'},
#  {'userId': 1,
#   'id': 2,
#   'title': 'qui est esse',
#   'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'},
#  {'userId': 1,
#   'id': 3,
#   'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'},
#  {'userId': 1,
#   'id': 4,
#   'title': 'eum et est occaecati',
# ...

# %%
df['town']
# Out:
# 0          Hyd
# 1          Hyd
# 2          Hyd
# 3          Hyd
# 4     Warangle
# 5    Nizamabad
# Name: town, dtype: object

# %%
data = pd.DataFrame([[1., 6.5, 3.],[1., np.nan, np.nan],

 [np.nan, np.nan, np.nan], [np.nan, 6.5, 3.]])

data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data[2].fillna(data[2].mean())
# Out:
# 0    3.0
# 1    3.0
# 2    3.0
# 3    3.0
# Name: 2, dtype: float64

# %%
data = {'A': [1, np.nan, 3, np.nan, 5],
        'B': [10, np.nan, np.nan, 40, 50],
        'C': [100, 200, 300, np.nan, np.nan]}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)

# Forward fill missing values
df_ffill = df.ffill()
print("\nDataFrame after forward fill:")
print(df_ffill)

# Backward fill missing values
df_bfill = df.bfill()
print("\nDataFrame after backward fill:")
print(df_bfill)
# Out:
# Original DataFrame:
#      A     B      C
# 0  1.0  10.0  100.0
# 1  NaN   NaN  200.0
# 2  3.0   NaN  300.0
# 3  NaN  40.0    NaN
# 4  5.0  50.0    NaN
#
# DataFrame after forward fill:
#      A     B      C
# 0  1.0  10.0  100.0
# 1  1.0  10.0  200.0
# 2  3.0  10.0  300.0
# 3  3.0  40.0  300.0
# 4  5.0  50.0  300.0
#
# DataFrame after backward fill:
#      A     B      C
# 0  1.0  10.0  100.0
# 1  3.0  40.0  200.0
# 2  3.0  40.0  300.0
# 3  5.0  40.0    NaN
# 4  5.0  50.0    NaN

# %%
df
# Out:
#      A     B      C
# 0  1.0  10.0  100.0
# 1  NaN   NaN  200.0
# 2  3.0   NaN  300.0
# 3  NaN  40.0    NaN
# 4  5.0  50.0    NaN

# %%
df.isna().any(axis=1)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
df['C'].fillna(df.mean(axis=0))
# Out:
# 0    100.0
# 1    200.0
# 2    300.0
# 3      NaN
# 4      NaN
# Name: C, dtype: float64

# %%
df
# Out:
#      A     B      C
# 0  1.0  10.0  100.0
# 1  NaN   NaN  200.0
# 2  3.0   NaN  300.0
# 3  NaN  40.0    NaN
# 4  5.0  50.0    NaN

# %%
df[df.isna().any(True)]
# Out:
# C:\Users\Sainath\AppData\Local\Temp\ipykernel_15896\4055427850.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   df[df.isna().any(True)]
#      A     B      C
# 1  NaN   NaN  200.0
# 2  3.0   NaN  300.0
# 3  NaN  40.0    NaN
# 4  5.0  50.0    NaN

# %%
df.isna().any(True)
# Out:
# C:\Users\Sainath\AppData\Local\Temp\ipykernel_15896\1363858266.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   df.isna().any(True)
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}
dwf = pd.DataFrame(data)
dwf
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
dwf1 = dwf.applymap(lambda x:x**2)
dwf1
# Out:
#    A   B   C
# 0  1  16  49
# 1  4  25  64
# 2  9  36  81

# %%
gender = pd.DataFrame({
    'names':['Akshitha', 'pavani', 'sai', 'hri'],
    'Gender':['F', 'F', 'M', 'M']
})
gender['Gender'].replace({
    'F':0,
    'M':1
}, inplace=True)
gender
# Out:
#       names  Gender
# 0  Akshitha       0
# 1    pavani       0
# 2       sai       1
# 3       hri       1
